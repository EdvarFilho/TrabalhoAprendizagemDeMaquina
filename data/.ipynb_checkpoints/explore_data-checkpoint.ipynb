# 28    Blackhawks Roster Breakdown: Goalies\n(Before ...      0
# 29    When Pulisic tore open the left side of the Pa...      1
# ...                                                 ...    ...
# 3979  A Potato Battery Can Light up a Room for Over ...      0
# 3980  Andy Murray during a practice session before p...      1
# 3981  Trump pushes for ‘no kneeling’ rule in NFL\n(B...      0
# 3982  An Embattled Pharmaceutical Company That Sells...      0
# 3983  (Before It's News)\nWas the Las Vegas massacre...      0
# 3984  Use the drop down lists to choose any two memb...      1
# 3985  The logo of commodities trader Glencore is pic...      1
# 3986  Image copyright AFP Image caption Carles Puigd...      1
# 3987  Services announced for Solomon Caesar, gospel ...      0
# 3988  Image copyright Alamy Image caption A judge ru...      1
# 3989  “I think all that strife, it kind of helped me...      1
# 3990  Saturday: Two To Go – Jamo v Max Scherzer, Lin...      0
# 3991  Matchup: Bulls v Mud Hens\n% of readers think ...      0
# 3992  By Jack Burns\n \nThe response time of the Las...      0
# 3993  An Embattled Pharmaceutical Company That Sells...      0
# 3994  By Catherine J. Frompovich\nOver a year ago, r...      0
# 3995  Image copyright Getty Images Image caption Har...      1
# 3996  The Spy in the IRA\n(Before It's News)\nIn the...      0
# 3997  Trump Takes Bold Action to Save U.S. From Euro...      0
# 3998  No Getting Around it, The War Is Coming! Trump...      0
# 3999  FILE PHOTO: Oct 25, 2013; St. Louis, MO, USA; ...      1
# 4000  By Nicholas West\nAll things biometric are swe...      0
# 4001  Mr. Leroux was born Hervé Peugnet on May 30, 1...      1
# 4002  Ethical questions loom after Vice President Mi...      1
# 4003  Vietnam Is in Great Danger, You Must Publish a...      0
# 4004  Trends to Watch\n% of readers think this story...      0
# 4005  Trump Jr. Is Soon To Give A 30-Minute Speech F...      0
# 4006                                                nan      0
# 4007  SHANGHAI (Reuters) - China said it plans to ac...      1
# 4008  Vice President Mike Pence Leaves NFL Game Beca...      0
#
# [4009 rows x 4 columns]

# %% [markdown]
# # 1. Brincando com os dados e gerando novas features

# %%
# Numero de 'palavras' nos Headlines
data['word_count'] = data['Headline'].apply(lambda x: len(str(x).split(" ")))
data.head()
# Out:
#                                                 URLs  \
# 0  http://www.bbc.com/news/world-us-canada-414191...
# 1  https://www.reuters.com/article/us-filmfestiva...
# 2  https://www.nytimes.com/2017/10/09/us/politics...
# 3  https://www.reuters.com/article/us-mexico-oil-...
# 4  http://www.cnn.com/videos/cnnmoney/2017/10/08/...
#
#                                             Headline  \
# 0         Four ways Bob Corker skewered Donald Trump
# 1  Linklater's war veteran comedy speaks to moder...
# 2  Trump’s Fight With Corker Jeopardizes His Legi...
# 3  Egypt's Cheiron wins tie-up with Pemex for Mex...
# 4        Jason Aldean opens 'SNL' with Vegas tribute
#
#                                                 Body  Label  word_count
# 0  Image copyright Getty Images\nOn Sunday mornin...      1           7
# 1  LONDON (Reuters) - “Last Flag Flying”, a comed...      1          10
# 2  The feud broke into public view last week when...      1           8
# 3  MEXICO CITY (Reuters) - Egypt’s Cheiron Holdin...      1          11
# 4  Country singer Jason Aldean, who was performin...      1           7

# %%
# Numero de 'caracteres' nos Headlines
data['char_count'] = data['Headline'].str.len() ## this also includes spaces
data.head()
# Out:
#                                                 URLs  \
# 0  http://www.bbc.com/news/world-us-canada-414191...
# 1  https://www.reuters.com/article/us-filmfestiva...
# 2  https://www.nytimes.com/2017/10/09/us/politics...
# 3  https://www.reuters.com/article/us-mexico-oil-...
# 4  http://www.cnn.com/videos/cnnmoney/2017/10/08/...
#
#                                             Headline  \
# 0         Four ways Bob Corker skewered Donald Trump
# 1  Linklater's war veteran comedy speaks to moder...
# 2  Trump’s Fight With Corker Jeopardizes His Legi...
# 3  Egypt's Cheiron wins tie-up with Pemex for Mex...
# 4        Jason Aldean opens 'SNL' with Vegas tribute
#
#                                                 Body  Label  word_count  \
# 0  Image copyright Getty Images\nOn Sunday mornin...      1           7
# 1  LONDON (Reuters) - “Last Flag Flying”, a comed...      1          10
# 2  The feud broke into public view last week when...      1           8
# 3  MEXICO CITY (Reuters) - Egypt’s Cheiron Holdin...      1          11
# 4  Country singer Jason Aldean, who was performin...      1           7
#
#    char_count
# 0          42
# 1          66
# 2          60
# 3          68
# 4          43

# %%
# Média de palavras nos Headlines
def avg_word(sentence):
  words = sentence.split()
  return (sum(len(word) for word in words)/len(words))

data['avg_word'] = data['Headline'].apply(lambda x: avg_word(x))
data.head()
# Out:
#                                                 URLs  \
# 0  http://www.bbc.com/news/world-us-canada-414191...
# 1  https://www.reuters.com/article/us-filmfestiva...
# 2  https://www.nytimes.com/2017/10/09/us/politics...
# 3  https://www.reuters.com/article/us-mexico-oil-...
# 4  http://www.cnn.com/videos/cnnmoney/2017/10/08/...
#
#                                             Headline  \
# 0         Four ways Bob Corker skewered Donald Trump
# 1  Linklater's war veteran comedy speaks to moder...
# 2  Trump’s Fight With Corker Jeopardizes His Legi...
# 3  Egypt's Cheiron wins tie-up with Pemex for Mex...
# 4        Jason Aldean opens 'SNL' with Vegas tribute
#
#                                                 Body  Label  word_count  \
# 0  Image copyright Getty Images\nOn Sunday mornin...      1           7
# 1  LONDON (Reuters) - “Last Flag Flying”, a comed...      1          10
# 2  The feud broke into public view last week when...      1           8
# 3  MEXICO CITY (Reuters) - Egypt’s Cheiron Holdin...      1          11
# 4  Country singer Jason Aldean, who was performin...      1           7
#
#    char_count  avg_word
# 0          42  5.142857
# 1          66  5.700000
# 2          60  6.625000
# 3          68  5.272727
# 4          43  5.285714

# %%
# Numero de 'stopwords' nos Headlines
data['stopwords'] = data['Headline'].apply(lambda x: len([x for x in x.split() if x in stop]))
data.head()
# Out:
#                                                 URLs  \
# 0  http://www.bbc.com/news/world-us-canada-414191...
# 1  https://www.reuters.com/article/us-filmfestiva...
# 2  https://www.nytimes.com/2017/10/09/us/politics...
# 3  https://www.reuters.com/article/us-mexico-oil-...
# 4  http://www.cnn.com/videos/cnnmoney/2017/10/08/...
#
#                                             Headline  \
# 0         Four ways Bob Corker skewered Donald Trump
# 1  Linklater's war veteran comedy speaks to moder...
# 2  Trump’s Fight With Corker Jeopardizes His Legi...
# 3  Egypt's Cheiron wins tie-up with Pemex for Mex...
# 4        Jason Aldean opens 'SNL' with Vegas tribute
#
#                                                 Body  Label  word_count  \
# 0  Image copyright Getty Images\nOn Sunday mornin...      1           7
# 1  LONDON (Reuters) - “Last Flag Flying”, a comed...      1          10
# 2  The feud broke into public view last week when...      1           8
# 3  MEXICO CITY (Reuters) - Egypt’s Cheiron Holdin...      1          11
# 4  Country singer Jason Aldean, who was performin...      1           7
#
#    char_count  avg_word  stopwords
# 0          42  5.142857          0
# 1          66  5.700000          1
# 2          60  6.625000          0
# 3          68  5.272727          2
# 4          43  5.285714          1

# %%
data['stopwordsBody'] = data['Body'].apply(lambda x: len([x for x in str(x).split() if str(x) in stop]))
data.head()
# Out:
#                                                 URLs  \
# 0  http://www.bbc.com/news/world-us-canada-414191...
# 1  https://www.reuters.com/article/us-filmfestiva...
# 2  https://www.nytimes.com/2017/10/09/us/politics...
# 3  https://www.reuters.com/article/us-mexico-oil-...
# 4  http://www.cnn.com/videos/cnnmoney/2017/10/08/...
#
#                                             Headline  \
# 0         Four ways Bob Corker skewered Donald Trump
# 1  Linklater's war veteran comedy speaks to moder...
# 2  Trump’s Fight With Corker Jeopardizes His Legi...
# 3  Egypt's Cheiron wins tie-up with Pemex for Mex...
# 4        Jason Aldean opens 'SNL' with Vegas tribute
#
#                                                 Body  Label  word_count  \
# 0  Image copyright Getty Images\nOn Sunday mornin...      1           7
# 1  LONDON (Reuters) - “Last Flag Flying”, a comed...      1          10
# 2  The feud broke into public view last week when...      1           8
# 3  MEXICO CITY (Reuters) - Egypt’s Cheiron Holdin...      1          11
# 4  Country singer Jason Aldean, who was performin...      1           7
#
#    char_count  avg_word  stopwords  stopwordsBody
# 0          42  5.142857          0            403
# 1          66  5.700000          1            201
# 2          60  6.625000          0            382
# 3          68  5.272727          2             29
# 4          43  5.285714          1             13

# %%
# Numero de 'hastags' nos Headlines
data['hastags'] = data['Headline'].apply(lambda x: len([x for x in x.split() if x.startswith('#')]))
data[data['hastags'] > 0] # vendo quais noticias possuem hashtags
# Out:
#                                                    URLs  \
# 223   http://beforeitsnews.com/sports/2017/10/108-hb...
# 245   http://beforeitsnews.com/sports/2017/09/929-fr...
# 373   http://beforeitsnews.com/sports/2017/09/around...
# 3934          52  4.888889          0              3        0         2
# 3948          38  4.571429          0            116        0         2
# 3967          31  4.333333          0            257        0         1
# 3978          53  5.000000          1            438        0         1
# 3984          51  7.666667          0              9        0         1
# 4000          93  5.714286          1            211        0         2
# 4001          66  4.583333          3            296        0         1
#
# [547 rows x 11 columns]

# %%
# Numero de uppers nos Headlines
data['upper'] = data['Headline'].apply(lambda x: len([x for x in x.split() if x.isupper()]))
data.head()
# Out:
#                                                 URLs  \
# 0  http://www.bbc.com/news/world-us-canada-414191...
# 1  https://www.reuters.com/article/us-filmfestiva...
# 2  https://www.nytimes.com/2017/10/09/us/politics...
# 3  https://www.reuters.com/article/us-mexico-oil-...
# 4  http://www.cnn.com/videos/cnnmoney/2017/10/08/...
#
#                                             Headline  \
# 0         Four ways Bob Corker skewered Donald Trump
# 1  Linklater's war veteran comedy speaks to moder...
# 2  Trump’s Fight With Corker Jeopardizes His Legi...
# 3  Egypt's Cheiron wins tie-up with Pemex for Mex...
# 4        Jason Aldean opens 'SNL' with Vegas tribute
#
#                                                 Body  Label  word_count  \
# 0  Image copyright Getty Images\nOn Sunday mornin...      1           7
# 1  LONDON (Reuters) - “Last Flag Flying”, a comed...      1          10
# 2  The feud broke into public view last week when...      1           8
# 3  MEXICO CITY (Reuters) - Egypt’s Cheiron Holdin...      1          11
# 4  Country singer Jason Aldean, who was performin...      1           7
#
#    char_count  avg_word  stopwords  stopwordsBody  hastags  numerics  upper
# 0          42  5.142857          0            403        0         0      0
# 1          66  5.700000          1            201        0         0      0
# 2          60  6.625000          0            382        0         0      0
# 3          68  5.272727          2             29        0         0      0
# 4          43  5.285714          1             13        0         0      1

# %%
# 10 Palavras mais frequentes
freqHeadline = pd.Series(' '.join(data['Headline']).split()).value_counts()[:10]
freqBody = pd.Series(' '.join(data['Body']).split()).value_counts()[:10]
rareHead = pd.Series(' '.join(data['Headline']).split()).value_counts()[-10:]
rareBody = pd.Series(' '.join(data['Body']).split()).value_counts()[-10:]

# %%
freqHeadline
# Out:
# to       718
# in       510
# the      423
# of       407
# The      378
# for      328
# Trump    294
# on       281
# -        262
# and      257
# dtype: int64

# %%
freqBody
# Out:
# the     96245
# to      50454
# of      44772
# and     44364
# a       41501
# in      35620
# that    18821
# is      17770
# for     17750
# on      17692
# dtype: int64

# %%
rareHead
# Out:
# surrender    1
# Hargan       1
# snake        1
# Drones:      1
# tech,        1
# albums       1
# Interpol     1
# Scout        1
# grass        1
# Agree?       1
# dtype: int64

# %%
rareBody
# Out:
# coughs,                 1
# Ukraine”                1
# swapped                 1
# “Marijuana              1
# diagnoses,              1
# turnover)               1
# Counter-demonstrator    1
# skiing,                 1
# tastes.                 1
# Hwasong-14,             1
# dtype: int64

# %% [markdown]
# # 2. Pré-processamento básico do dado

# %%
# Deixar tudo em lower case
data['Headline'] = data['Headline'].apply(lambda x: " ".join(x.lower() for x in x.split()))
data['Body'] = data['Body'].apply(lambda x: " ".join(x.lower() for x in str(x).split()))
data.head()
# Out:
#                                                 URLs  \
# 0  http://www.bbc.com/news/world-us-canada-414191...
# 1  https://www.reuters.com/article/us-filmfestiva...
# 2  https://www.nytimes.com/2017/10/09/us/politics...
# 3  https://www.reuters.com/article/us-mexico-oil-...
# 4  http://www.cnn.com/videos/cnnmoney/2017/10/08/...
#
#                                             Headline  \
# 0         four ways bob corker skewered donald trump
# 1  linklater's war veteran comedy speaks to moder...
# 2  trump’s fight with corker jeopardizes his legi...
# 3  egypt's cheiron wins tie-up with pemex for mex...
# 4        jason aldean opens 'snl' with vegas tribute
#
#                                                 Body  Label  word_count  \
# 0  image copyright getty images on sunday morning...      1           7
# 1  london (reuters) - “last flag flying”, a comed...      1          10
# 2  the feud broke into public view last week when...      1           8
# 3  mexico city (reuters) - egypt’s cheiron holdin...      1          11
# 4  country singer jason aldean, who was performin...      1           7
#
#    char_count  avg_word  stopwords  stopwordsBody  hastags  numerics  upper
# 0          42  5.142857          0            403        0         0      0
# 1          66  5.700000          1            201        0         0      0
# 2          60  6.625000          0            382        0         0      0
# 3          68  5.272727          2             29        0         0      0
# 4          43  5.285714          1             13        0         0      1

# %%
# Removendo pontuação
data['Headline'] = data['Headline'].str.replace('[^\w\s]','')
data['Body'] = data['Body'].str.replace('[^\w\s]','')
data.head()
# Out:
#                                                 URLs  \
# 0  http://www.bbc.com/news/world-us-canada-414191...
# 1  https://www.reuters.com/article/us-filmfestiva...
# 2  https://www.nytimes.com/2017/10/09/us/politics...
# 3  https://www.reuters.com/article/us-mexico-oil-...
# 4  http://www.cnn.com/videos/cnnmoney/2017/10/08/...
#
#                                             Headline  \
# 0         four ways bob corker skewered donald trump
# 1  linklaters war veteran comedy speaks to modern...
# 2  trumps fight with corker jeopardizes his legis...
# 3  egypts cheiron wins tieup with pemex for mexic...
# 4          jason aldean opens snl with vegas tribute
#
#                                                 Body  Label  word_count  \
# 0  image copyright getty images on sunday morning...      1           7
# 1  london reuters  last flag flying a comedydrama...      1          10
# 2  the feud broke into public view last week when...      1           8
# 3  mexico city reuters  egypts cheiron holdings l...      1          11
# 4  country singer jason aldean who was performing...      1           7
#
#    char_count  avg_word  stopwords  stopwordsBody  hastags  numerics  upper
# 0          42  5.142857          0            403        0         0      0
# 1          66  5.700000          1            201        0         0      0
# 2          60  6.625000          0            382        0         0      0
# 3          68  5.272727          2             29        0         0      0
# 4          43  5.285714          1             13        0         0      1

# %%
data['Headline'] = data['Headline'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
data['Headline'] = data['Headline'].apply(lambda x: " ".join(x for x in str(x).split() if str(x) not in stop))
data.head()
# Out:
#                                                 URLs  \
# 0  http://www.bbc.com/news/world-us-canada-414191...
# 1  https://www.reuters.com/article/us-filmfestiva...
# 2  https://www.nytimes.com/2017/10/09/us/politics...
# 3  https://www.reuters.com/article/us-mexico-oil-...
# 4  http://www.cnn.com/videos/cnnmoney/2017/10/08/...
#
#                                             Headline  \
# 0         four ways bob corker skewered donald trump
# 1  linklaters war veteran comedy speaks modern am...
# 2  trumps fight corker jeopardizes legislative ag...
# 3  egypts cheiron wins tieup pemex mexican onshor...
# 4               jason aldean opens snl vegas tribute
#
#                                                 Body  Label  word_count  \
# 0  image copyright getty images on sunday morning...      1           7
# 1  london reuters  last flag flying a comedydrama...      1          10
# 2  the feud broke into public view last week when...      1           8
# 3  mexico city reuters  egypts cheiron holdings l...      1          11
# 4  country singer jason aldean who was performing...      1           7
#
#    char_count  avg_word  stopwords  stopwordsBody  hastags  numerics  upper
# 0          42  5.142857          0            403        0         0      0
# 1          66  5.700000          1            201        0         0      0
# 2          60  6.625000          0            382        0         0      0
# 3          68  5.272727          2             29        0         0      0
# 4          43  5.285714          1             13        0         0      1

# %%
# 10 Palavras mais frequentes - Atualizando
freqHeadline = pd.Series(' '.join(data['Headline']).split()).value_counts()[:10]
freqBody = pd.Series(' '.join(data['Body']).split()).value_counts()[:10]
rareHead = pd.Series(' '.join(data['Headline']).split()).value_counts()[-10:]
rareBody = pd.Series(' '.join(data['Body']).split()).value_counts()[-10:]

# %%
# Remoção das palavras raras e frequentes
freqHeadline = list(freqHeadline.index)
freqBody = list(freqBody.index)
data['Headline'] = data['Headline'].apply(lambda x: " ".join(x for x in x.split() if x not in freqHeadline))
data['Body'] = data['Body'].apply(lambda x: " ".join(x for x in x.split() if x not in freqBody))
data['Headline'] = data['Headline'].apply(lambda x: " ".join(x for x in x.split() if x not in rareHead))
data['Body'] = data['Body'].apply(lambda x: " ".join(x for x in x.split() if x not in rareBody))
data.head()
# Out:
#                                                 URLs  \
# 0  http://www.bbc.com/news/world-us-canada-414191...
# 1  https://www.reuters.com/article/us-filmfestiva...
# 2  https://www.nytimes.com/2017/10/09/us/politics...
# 3  https://www.reuters.com/article/us-mexico-oil-...
# 4  http://www.cnn.com/videos/cnnmoney/2017/10/08/...
#
#                                             Headline  \
# 0               four ways bob corker skewered donald
# 1  linklaters war veteran comedy speaks modern am...
# 2  trumps fight corker jeopardizes legislative ag...
# 3  egypts cheiron wins tieup pemex mexican onshor...
# 4                     jason aldean opens snl tribute
#
#                                                 Body  Label  word_count  \
# 0  image copyright getty images sunday morning do...      1           7
# 1  london reuters last flag flying comedydrama ab...      1          10
# 2  feud broke into public view last week when mr ...      1           8
# 3  mexico city reuters egypts cheiron holdings li...      1          11
# 4  country singer jason aldean who was performing...      1           7
#
#    char_count  avg_word  stopwords  stopwordsBody  hastags  numerics  upper
# 0          42  5.142857          0            403        0         0      0
# 1          66  5.700000          1            201        0         0      0
# 2          60  6.625000          0            382        0         0      0
# 3          68  5.272727          2             29        0         0      0
# 4          43  5.285714          1             13        0         0      1

# %%
# Correção ortografica dos dados
data['Headline'] = data['Headline'].apply(lambda x: str(TextBlob(x).correct()))
data['Body'] = data['Body'].apply(lambda x: str(TextBlob(x).correct()))
data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-1916fefbf83b> in <module>
#       1 # Correção ortografica dos dados
# ----> 2 data['Headline'] = data['Headline'].apply(lambda x: str(TextBlob(x).correct()))
#       3 data['Body'] = data['Body'].apply(lambda x: str(TextBlob(x).correct()))
#       4 data.head()
#
# ~\Miniconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-34-1916fefbf83b> in <lambda>(x)
#       1 # Correção ortografica dos dados
# ----> 2 data['Headline'] = data['Headline'].apply(lambda x: str(TextBlob(x).correct()))
#       3 data['Body'] = data['Body'].apply(lambda x: str(TextBlob(x).correct()))
#       4 data.head()
#
# ~\Miniconda3\lib\site-packages\textblob\blob.py in correct(self)
#     578         tokens = nltk.tokenize.regexp_tokenize(self.raw, r"\w+|[^\w\s]|\s")
#     579         corrected = (Word(w).correct() for w in tokens)
# --> 580         ret = ''.join(corrected)
#     581         return self.__class__(ret)
#     582
#
# ~\Miniconda3\lib\site-packages\textblob\blob.py in <genexpr>(.0)
#     577         # regex matches: word or punctuation or whitespace
#     578         tokens = nltk.tokenize.regexp_tokenize(self.raw, r"\w+|[^\w\s]|\s")
# --> 579         corrected = (Word(w).correct() for w in tokens)
#     580         ret = ''.join(corrected)
#     581         return self.__class__(ret)
#
# ~\Miniconda3\lib\site-packages\textblob\blob.py in correct(self)
#     125         .. versionadded:: 0.6.0
#     126         '''
# --> 127         return Word(self.spellcheck()[0][0])
#     128
#     129     @cached_property
#
# ~\Miniconda3\lib\site-packages\textblob\blob.py in spellcheck(self)
#     117         .. versionadded:: 0.6.0
#     118         '''
# --> 119         return suggest(self.string)
#     120
#     121     def correct(self):
#
# ~\Miniconda3\lib\site-packages\textblob\en\__init__.py in suggest(w)
#     121     """ Returns a list of (word, confidence)-tuples of spelling corrections.
#     122     """
# --> 123     return spelling.suggest(w)
#     124
#     125 def polarity(s, **kwargs):
#
# ~\Miniconda3\lib\site-packages\textblob\_text.py in suggest(self, w)
#    1396         candidates = self._known([w]) \
#    1397                   or self._known(self._edit1(w)) \
# -> 1398                   or self._known(self._edit2(w)) \
#    1399                   or [w]
#    1400         candidates = [(self.get(c, 0.0), c) for c in candidates]
#
# ~\Miniconda3\lib\site-packages\textblob\_text.py in _edit2(self, w)
#    1373         # Of all spelling errors, 99% is covered by edit distance 2.
#    1374         # Only keep candidates that are actually known words (20% speedup).
# -> 1375         return set(e2 for e1 in self._edit1(w) for e2 in self._edit1(e1) if e2 in self)
#    1376
#    1377     def _known(self, words=[]):
#
# ~\Miniconda3\lib\site-packages\textblob\_text.py in <genexpr>(.0)
#    1373         # Of all spelling errors, 99% is covered by edit distance 2.
#    1374         # Only keep candidates that are actually known words (20% speedup).
# -> 1375         return set(e2 for e1 in self._edit1(w) for e2 in self._edit1(e1) if e2 in self)
#    1376
#    1377     def _known(self, words=[]):
#
# ~\Miniconda3\lib\site-packages\textblob\_text.py in __contains__(self, *args)
#      94         return self._lazy("__iter__")
#      95     def __contains__(self, *args):
# ---> 96         return self._lazy("__contains__", *args)
#      97     def __getitem__(self, *args):
#      98         return self._lazy("__getitem__", *args)
#
# ~\Miniconda3\lib\site-packages\textblob\_text.py in _lazy(self, method, *args)
#      85             self.load()
#      86             setattr(self, method, types.MethodType(getattr(dict, method), self))
# ---> 87         return getattr(dict, method)(self, *args)
#      88
#      89     def __repr__(self):
#
# KeyboardInterrupt:

# %%
# Tokenize os dados
TextBlob(data['Headline'][1]).words
# Out:
# WordList(['linklaters', 'war', 'veteran', 'comedy', 'speaks', 'modern', 'america', 'star'])

# %%
# Stemming refers to the removal of suffices, like “ing”, “ly”, “s”, etc
#from nltk.stem import PorterStemmer
#st = PorterStemmer()
#data['Headline'] = data['Headline'].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))
#data['Body'] = data['Body'].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))
#data.head()

# %%
# Lemmatization is a more effective option than stemming because it converts the word into its root word, 
# rather than just stripping the suffices. 
# It makes use of the vocabulary and does a morphological analysis to obtain the root word

from textblob import Word
import nltk
nltk.download('wordnet')
data['Headline'] = data['Headline'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
data['Body'] = data['Body'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
data.head()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\andre\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
#                                                 URLs  \
# 0  http://www.bbc.com/news/world-us-canada-414191...
# 1  https://www.reuters.com/article/us-filmfestiva...
# 2  https://www.nytimes.com/2017/10/09/us/politics...
# 3  https://www.reuters.com/article/us-mexico-oil-...
# 4  http://www.cnn.com/videos/cnnmoney/2017/10/08/...
#
#                                             Headline  \
# 0                  four way bob corker skewer donald
# 1  linklat war veteran comedi speak modern americ...
# 2           trump fight corker jeopard legisl agenda
# 3  egypt cheiron win tieup pemex mexican onshor o...
# 4                       jason aldean open snl tribut
#
#                                                 Body  Label  word_count  \
# 0  imag copyright getti imag sunday morn donald t...      1           7
# 1  london reuter last flag fli comedydrama about ...      1          10
# 2  feud broke into public view last week when mr ...      1           8
# 3  mexico citi reuter egypt cheiron hold limit wo...      1          11
# 4  countri singer jason aldean who wa perform a l...      1           7
#
#    char_count  avg_word  stopwords  stopwordsBody  hastags  numerics  upper
# 0          42  5.142857          0            403        0         0      0
# 1          66  5.700000          1            201        0         0      0
# 2          60  6.625000          0            382        0         0      0
# 3          68  5.272727          2             29        0         0      0
# 4          43  5.285714          1             13        0         0      1

# %% [markdown]
# # Técnicas avançadas de processamento
